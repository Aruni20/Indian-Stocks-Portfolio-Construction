# %% [markdown]
# # 01 Data preparation
#
# This executed notebook documents the prepared Indian equity dataset and its availability.

# %%
from pathlib import Path
import csv
ROOT = Path("..")
availability = ROOT / "outputs" / "data_availability.json"
print(availability.read_text())
# Out:
# {
#   "Auto": [],
#   "Banking": [],
#   "Consumer Durable": [],
#   "FMCG": [],
#   "Healthcare": [],
#   "IT": [
#     "Mindtree"
#   ],
#   "Metal": []
# }

# %%
import csv
path = ROOT / "outputs" / "constituent_metrics.csv"
with path.open() as f:
    rows = list(csv.reader(f))
for row in rows[:6]: print(row)
# Out:
# sector,stock,annual_return,annual_risk,training_days
# Auto,Maruti Suzuki,0.18146895782419772,0.2380932105295906,1242
# Auto,Mahindra & Mahindra,0.41398894384291807,0.29249567485407263,1242
# Auto,Tata Motors,0.45667667610055873,0.37484222325915717,1242
# Auto,Hero MotoCorp,0.14982008678349162,0.2612722347438818,1242
# Auto,Eicher Motors,0.2631100450236488,0.27339331276970136,1242
