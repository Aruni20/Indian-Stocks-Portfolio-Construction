# %% [markdown]
# # 01. Data preparation
# Convert minute OHLCV data to daily closes and simple returns.

# %%
from pathlib import Path
import sys
ROOT=Path.cwd().parent
sys.path.insert(0,str(ROOT))
import pandas as pd
input_path=ROOT/"data/raw/prices.csv"
print("Expected input:",input_path)
