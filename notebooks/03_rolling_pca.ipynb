# %% [markdown]
# # 03 Rolling PCA
#
# One-year trailing-window PCA weights with monthly, quarterly, half-yearly, and yearly rebalance comparisons.

# %%
import csv
from pathlib import Path
ROOT=Path("..")
path=ROOT/"outputs"/"rolling_pca_yearly_returns.csv"
with path.open() as f:
    rows=list(csv.reader(f))
for row in rows[:15]: print(row)
# Out:
# sector,frequency,year,annual_return,trading_days
# Auto,monthly,2017,0.5092765083397062,248
# Auto,monthly,2018,-0.17582291656717175,246
# Auto,monthly,2019,-0.041969652099779986,245
# Auto,monthly,2020,0.2351240443062994,252
# Auto,monthly,2021,0.2525962645759161,248
# Auto,monthly,2022,0.1079645002279419,248
# Auto,monthly,2023,0.435465914036282,246
# Auto,monthly,2024,0.08783602264766466,249
# Auto,monthly,2025,0.30592605542303364,249
# Auto,monthly,2026,-0.004303588910660183,11
# Auto,quarterly,2017,0.6143596006790737,248
# Auto,quarterly,2018,-0.18796217314696761,246
# Auto,quarterly,2019,-0.05642445949940689,245
# Auto,quarterly,2020,0.31113928232205423,252

# %%
path=ROOT/"outputs"/"rolling_pca_full_report.md"
print(path.read_text())
# Out:
# # One-year rolling PCA portfolio report
#
# Each calendar year uses the preceding one-year return history to estimate PCA weights. The portfolio is rebalanced monthly, quarterly, half-yearly, or yearly. Results cover 2017 through the latest available 2026 observations.
#
# At each rebalance, returns are standardized, PCA is computed by SVD, and the best-Sharpe portfolio among the first five principal components is selected. Component loadings are converted to long-only normalized weights.
#
# ## Average return across sectors
#
# | year | half_yearly | monthly | quarterly | yearly |
# |---|---|---|---|---|
# | 2017 | 36.87% | 38.51% | 37.23% | 34.46% |
# | 2018 | 2.20% | 1.82% | 1.55% | 3.34% |
# | 2019 | 11.28% | 8.85% | 11.83% | 13.91% |
# | 2020 | 52.53% | 56.44% | 62.33% | 46.85% |
# | 2021 | 45.58% | 50.26% | 47.42% | 51.65% |
# | 2022 | 8.76% | 5.96% | 7.72% | 0.97% |
# | 2023 | 27.26% | 26.40% | 28.03% | 19.88% |
# | 2024 | 24.06% | 21.79% | 24.16% | 22.22% |
# ...
