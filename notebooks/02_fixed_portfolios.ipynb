# %% [markdown]
# # 02 Fixed portfolios
#
# Executed results for equal weight, minimum risk, optimum risk, and eigen portfolio comparisons.

# %%
import csv
from pathlib import Path
ROOT=Path("..")
path=ROOT/"outputs"/"in_sample_metrics.csv"
with path.open() as f:
    rows=list(csv.reader(f))
for row in rows: print(row)
# Out:
# sector,method,annual_return,annual_risk,sharpe,training_days
# Auto,minimum_variance,0.1935488656170005,0.17813098937018054,1.0304151246561644,1242
# Auto,maximum_sharpe,0.3885250354243745,0.24420309905976748,1.550041899065877,1242
# Auto,eigen,0.293131952660159,0.20431279537382827,1.3857769022352047,1242
# Banking,minimum_variance,0.19584000159353465,0.19086155319210327,0.9736900831278764,1242
# Banking,maximum_sharpe,0.304071880991791,0.2190384523065922,1.3425582489971812,1242
# Banking,eigen,0.24731773995671227,0.21438917358639564,1.1069483406589873,1242
# Consumer Durable,minimum_variance,0.10410178040688536,0.15932032906245477,0.5906451547058804,1242
# Consumer Durable,maximum_sharpe,0.3675939968051509,0.21144538627480902,1.6911884581884282,1242

# %%
path=ROOT/"outputs"/"holdout_returns.csv"
with path.open() as f:
    rows=list(csv.reader(f))
for row in rows: print(row)
# Out:
# sector,method,holdout_start,holdout_end,holdout_days,six_month_return
# Auto,minimum_variance,2025-07-01,2025-12-31,126,0.19141415212225943
# Auto,maximum_sharpe,2025-07-01,2025-12-31,126,0.0917651327002893
# Auto,eigen,2025-07-01,2025-12-31,126,0.1492774071763312
# Banking,minimum_variance,2025-07-01,2025-12-31,126,0.023037391823512055
# Banking,maximum_sharpe,2025-07-01,2025-12-31,126,0.0774068994831767
# Banking,eigen,2025-07-01,2025-12-31,126,0.10572572365224264
# Consumer Durable,minimum_variance,2025-07-01,2025-12-31,126,-0.133218576625161
# Consumer Durable,maximum_sharpe,2025-07-01,2025-12-31,126,-0.07144386885278264
