# %% [markdown]
# # 04. Performance analysis
# Calculate cumulative return, CAGR, volatility, Sharpe, Sortino, drawdown, and Calmar.

# %%
from pathlib import Path
import sys
ROOT=Path.cwd().parent
sys.path.insert(0,str(ROOT))
from src.metrics import performance_metrics
print("Metrics imported")
